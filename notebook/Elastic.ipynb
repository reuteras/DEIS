# %% [markdown]
# # Elasticsearch
#
# More information about the elasticsearch Python package can be found at [elastic.co](https://www.elastic.co/guide/en/elasticsearch/client/python-api/current/getting-started-python.html) and in the [documentation](https://elasticsearch-py.readthedocs.io/en/latest/).

# %%
# %%bash -e
# python3 -m pip -q install --upgrade pip
# python3 -m pip -q install "elasticsearch==9.5.0" numpy pandas ipywidgets "wordcloud==1.9.6"

# %%
# Python imports
import os

import ipywidgets as widgets
import pandas as pd
from IPython.display import display

from elasticsearch import Elasticsearch

# %%
# Connect to elastic and create variables
INDEX = "leakdata-index-000001"  # must match ingest.py's INDEX
es = Elasticsearch("http://elasticsearch:9200", basic_auth=("elastic", os.environ["ELASTIC_PASSWORD"]))

# %%
# Term to search for
search_term = "secret"

# %%
# Retrieve results from elastic and build the dataframe.
DEFAULT_SEARCH_TERM = search_term
on_search_callbacks = []

results_table = widgets.HTML()


def render_results_table():
    if df.empty:
        results_table.value = "<p>No results.</p>"
        return
    rows = "".join(f"<tr><td>{fname}</td><td>{links}</td></tr>" for fname, links in zip(df["filename"], df["links"]))
    results_table.value = f"<table><thead><tr><th>Filename</th><th>Links</th></tr></thead><tbody>{rows}</tbody></table>"


def run_search(term):
    """Query Elasticsearch for term and (re)build results/df from the hits."""
    global search_term, results, sha_list, filename_list, df

    search_term = term
    results = []
    sha_list = []
    filename_list = []

    response = es.search(index=INDEX, size="10000", query={"match": {"attachment.content": term}})
    print(f"Recieved {response['hits']['total']['value']} hits for search term '{term}'.")
    for hit in response["hits"]["hits"]:
        results.append(
            [
                hit["_source"]["filename"].replace("extracted/files/", ""),
                hit["_source"]["sha256"],
                hit["_source"]["attachment"]["content"],
            ]
        )
        sha_list.append(hit["_source"]["sha256"])
        filename_list.append(hit["_source"]["filename"])

    df = pd.DataFrame(data=results, columns=["filename", "sha256", "content"])
    # Two separate links per result - preview (opens the Gotenberg-converted
    # PDF inline, in a new tab) vs download (forces a save of the original
    # file, unconverted) - rather than a single link that only did one or
    # the other with no way to choose.
    df["links"] = df["sha256"].apply(
        lambda x: (
            f'<a href="http://127.0.0.1:8081/convert/{x}" target="_blank">Preview</a> | '
            f'<a href="http://127.0.0.1:8081/file/{x}?disposition=attachment" target="_blank">Download</a>'
        )
    )
    render_results_table()


def search_and_refresh(term):
    """Run a new search, then refresh everything that depends on it.

    Cells below register their own refresh function into on_search_callbacks
    when they run (see compute_word_analysis / refresh_preview), so this
    doesn't need to know those functions by name - it just replays whatever
    has been registered so far. That also means it stays correct regardless
    of which of those cells has (or hasn't) run yet.
    """
    run_search(term)
    for callback in on_search_callbacks:
        callback()


display(results_table)
run_search(search_term)

# %%
# Word cloud and most-common-words table, built once from the full corpus
# ("content" field across every document in the index, produced by the
# attachment/cbor-attachment ingest pipeline via Apache Tika) rather than
# from the current document search below - so changing search_term or
# clicking a word to search doesn't change the cloud. Click a word in the
# table to search for it (same as changing search_term and re-running the
# search cell by hand, just wired to a click); "Reset search" goes back to
# the search_term value the notebook started with. Neither affects the
# cloud/table above - only the document search and preview below them.
#
# wordcloud's built-in STOPWORDS list is English only. Swedish and
# Portuguese lists are added below as plain static word lists (not
# exhaustive, but covers the common function words) rather than pulling in
# a package like nltk, which would also need a runtime corpus download for
# this. Set wordcloud_language to match what you're reviewing, e.g.
# "english", "swedish", "portuguese", or "+"-combined like "english+swedish".

import base64
from collections import Counter
from io import BytesIO

from wordcloud import STOPWORDS, WordCloud

wordcloud_language = "english+swedish"

SWEDISH_STOPWORDS = {
    "och",
    "det",
    "att",
    "i",
    "en",
    "jag",
    "hon",
    "som",
    "han",
    "på",
    "den",
    "med",
    "var",
    "sig",
    "för",
    "så",
    "till",
    "är",
    "men",
    "ett",
    "om",
    "hade",
    "de",
    "av",
    "icke",
    "mig",
    "du",
    "henne",
    "då",
    "sin",
    "nu",
    "har",
    "inte",
    "hans",
    "honom",
    "skulle",
    "hennes",
    "där",
    "min",
    "man",
    "ej",
    "vid",
    "kunde",
    "något",
    "från",
    "ut",
    "när",
    "efter",
    "upp",
    "vi",
    "dem",
    "vara",
    "vad",
    "över",
    "än",
    "dig",
    "kan",
    "sina",
    "här",
    "ha",
    "mot",
    "alla",
    "under",
    "någon",
    "eller",
    "allt",
    "mycket",
    "sedan",
    "ju",
    "denna",
    "själv",
    "detta",
    "åt",
    "blivit",
    "dess",
    "inom",
    "mellan",
    "sådan",
    "varför",
    "varje",
    "vilken",
    "vilka",
    "vilket",
    "vars",
    "vart",
    "varken",
    "varmed",
    "varpå",
    "vartill",
    "vore",
    "annan",
    "annat",
    "andra",
    "dessa",
    "varit",
    "hur",
    "även",
    "eftersom",
    "medan",
    "före",
    "just",
    "några",
    "er",
    "eder",
    "vår",
    "vårt",
    "våra",
    "din",
    "ditt",
    "dina",
    "sitt",
    "kanske",
    "genom",
    "bara",
    "redan",
    "fram",
    "genast",
    "två",
    "tre",
    "fyra",
    "fem",
    "sex",
    "sju",
    "åtta",
    "nio",
    "tio",
}

PORTUGUESE_STOPWORDS = {
    "de",
    "a",
    "o",
    "que",
    "e",
    "do",
    "da",
    "em",
    "um",
    "para",
    "com",
    "não",
    "uma",
    "os",
    "no",
    "se",
    "na",
    "por",
    "mais",
    "as",
    "dos",
    "como",
    "mas",
    "ao",
    "ele",
    "das",
    "seu",
    "sua",
    "ou",
    "quando",
    "muito",
    "nos",
    "já",
    "eu",
    "também",
    "só",
    "pelo",
    "pela",
    "até",
    "isso",
    "ela",
    "entre",
    "depois",
    "sem",
    "mesmo",
    "aos",
    "seus",
    "quem",
    "nas",
    "me",
    "esse",
    "eles",
    "você",
    "essa",
    "num",
    "nem",
    "suas",
    "meu",
    "minha",
    "numa",
    "pelos",
    "elas",
    "qual",
    "nós",
    "lhe",
    "deles",
    "essas",
    "esses",
    "pelas",
    "este",
    "dele",
    "tu",
    "te",
    "vocês",
    "vos",
    "lhes",
    "meus",
    "minhas",
    "teu",
    "tua",
    "teus",
    "tuas",
    "nosso",
    "nossa",
    "nossos",
    "nossas",
    "dela",
    "delas",
    "esta",
    "estes",
    "estas",
    "aquele",
    "aquela",
    "aqueles",
    "aquelas",
    "isto",
    "aquilo",
    "é",
    "são",
    "foi",
    "está",
    "estão",
}

WORDCLOUD_STOPWORDS_BY_LANGUAGE = {
    "english": STOPWORDS,
    "swedish": SWEDISH_STOPWORDS,
    "portuguese": PORTUGUESE_STOPWORDS,
}


def get_stopwords():
    stopwords = set()
    for lang in wordcloud_language.split("+"):
        stopwords |= WORDCLOUD_STOPWORDS_BY_LANGUAGE[lang.strip().lower()]
    return stopwords


def fetch_term_counts(size=1000):
    """Top terms across the whole corpus and their document counts, computed
    server-side by Elasticsearch - no document content is pulled here.
    """
    response = es.search(
        index=INDEX,
        size=0,
        query={"match_all": {}},
        aggs={"top_words": {"terms": {"field": "attachment.content", "size": size}}},
    )
    buckets = response["aggregations"]["top_words"]["buckets"]
    return {b["key"]: b["doc_count"] for b in buckets}


word_counts = Counter()
top_n_words = widgets.BoundedIntText(value=10, min=1, max=200, description="Top N words:")
reset_button = widgets.Button(description="Reset search")
wordcloud_image = widgets.HTML()
word_table = widgets.VBox()


def render_word_table():
    rows = []
    for word, count in word_counts.most_common(top_n_words.value):
        button = widgets.Button(description=f"{word}  ({count})", layout=widgets.Layout(width="300px"))
        button.on_click(on_word_clicked(word))
        rows.append(button)
    word_table.children = rows


def on_word_clicked(word):
    def handler(_):
        search_and_refresh(word)

    return handler


def on_reset_clicked(_):
    search_and_refresh(DEFAULT_SEARCH_TERM)


def compute_word_analysis():
    global word_counts

    term_counts = fetch_term_counts()
    stopwords = get_stopwords()
    word_counts = Counter(
        {word: count for word, count in term_counts.items() if word not in stopwords and len(word) > 2}
    )

    if not word_counts:
        wordcloud_image.value = "<p>No text content to build a word cloud from.</p>"
        render_word_table()
        return

    cloud = WordCloud(width=1200, height=600, background_color="white").generate_from_frequencies(word_counts)
    buf = BytesIO()
    cloud.to_image().save(buf, format="PNG")
    encoded = base64.b64encode(buf.getvalue()).decode("ascii")
    wordcloud_image.value = f'<img src="data:image/png;base64,{encoded}" style="max-width: 1200px;">'
    render_word_table()


top_n_words.observe(lambda change: render_word_table(), names="value")
reset_button.on_click(on_reset_clicked)
# Not registered in on_search_callbacks: the cloud/table are built once from
# the full corpus and are intentionally left alone by searches/resets.

display(widgets.HBox([top_n_words, reset_button]), wordcloud_image, word_table)
compute_word_analysis()
# Out:
# ...
# HTML(value='')
# VBox()

# %%
# Interactive document preview.
#
# JupyterLab's HTML sanitizer strips inline <script> tags and onclick=
# handlers from display(HTML(...)) output (XSS mitigation), so the old
# raw-HTML Previous/Next buttons silently did nothing under current
# JupyterLab. ipywidgets communicates over the Jupyter comm protocol
# instead of injected HTML/JS, so button clicks are handled here.
#
# The preview itself is a plain widgets.HTML whose .value we overwrite
# with a fresh <iframe> string (a single atomic trait update). An Output
# widget with clear_output()+display() has a known race the first time
# it's updated right after being pre-populated before its own first
# render: the frontend can end up mounting a second, orphaned view
# instead of updating the existing one. A plain HTML widget doesn't have
# that failure mode.
current_index = 0

prev_button = widgets.Button(description="Previous")
next_button = widgets.Button(description="Next")
label = widgets.Label()
download_link = widgets.HTML()
preview_frame = widgets.HTML()


def show_doc(index):
    global current_index
    current_index = index
    if not sha_list:
        label.value = "No documents to preview."
        download_link.value = ""
        preview_frame.value = ""
        return
    sha = sha_list[index]
    label.value = f"Document {index + 1}/{len(sha_list)}: {filename_list[index]} ({sha})"
    # The iframe below previews the Gotenberg-converted PDF inline; this link
    # is for the original, unconverted file, forced as a download rather
    # than another inline preview.
    download_link.value = (
        f'<a href="http://127.0.0.1:8081/file/{sha}?disposition=attachment" target="_blank">Download original</a>'
    )
    preview_frame.value = (
        f'<iframe src="http://127.0.0.1:8081/convert/{sha}" width="1150" height="850" style="border: none;"></iframe>'
    )


def refresh_preview():
    show_doc(0)


def on_prev_clicked(_):
    if current_index > 0:
        show_doc(current_index - 1)


def on_next_clicked(_):
    if current_index < len(sha_list) - 1:
        show_doc(current_index + 1)


prev_button.on_click(on_prev_clicked)
next_button.on_click(on_next_clicked)
on_search_callbacks.append(refresh_preview)

display(widgets.HBox([prev_button, next_button]), label, download_link, preview_frame)
refresh_preview()
